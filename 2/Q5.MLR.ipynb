# %%
import pandas as pd
df=pd.read_csv(r"D:\datasets\data.csv")
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.sample(5)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 203   2014-05-06 00:00:00  530000.0       5.0       2.50         2910
# 4077  2014-07-08 00:00:00  357562.0       2.0       1.75         1210
# 3772  2014-07-01 00:00:00  600000.0       2.0       1.00          910
# 1896  2014-06-04 00:00:00  310000.0       3.0       2.00         1350
# 1157  2014-05-22 00:00:00  432000.0       3.0       2.25         1470
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 203       9636     1.0           0     0          4        1690
# 4077      1032     2.0           0     0          3        1210
# 3772      2002     1.5           0     0          3         910
# 1896     11150     1.0           0     0          3        1110
# 1157      1578     2.0           0     0          3        1090
#
#       sqft_basement  yr_built  yr_renovated                  street  \
# 203            1220      1964             0       3250 165th Ave SE
# ...

# %%
corr=df.corr()
corr.style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_4ac1f_row0_col0, #T_4ac1f_row1_col1, #T_4ac1f_row2_col2, #T_4ac1f_row3_col3, #T_4ac1f_row4_col4, #T_4ac1f_row5_col5, #T_4ac1f_row6_col6, #T_4ac1f_row7_col7, #T_4ac1f_row8_col8, #T_4ac1f_row9_col9, #T_4ac1f_row10_col10, #T_4ac1f_row11_col11, #T_4ac1f_row12_col12 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_4ac1f_row0_col1, #T_4ac1f_row6_col12 {
#   background-color: #01b3ec;
#   color: #f1f1f1;
# }
# #T_4ac1f_row0_col2, #T_4ac1f_row3_col0 {
#   background-color: #64fbc3;
#   color: #000000;
# }
# #T_4ac1f_row0_col3 {
#   background-color: #7dffb6;
#   color: #000000;
# }
# #T_4ac1f_row0_col4, #T_4ac1f_row11_col4 {
#   background-color: #5c38fd;
#   color: #f1f1f1;
# }
# #T_4ac1f_row0_col5, #T_4ac1f_row4_col9 {
#   background-color: #2adddd;
#   color: #000000;
# }
# #T_4ac1f_row0_col6 {
#   background-color: #3176f8;
#   color: #f1f1f1;
# }
# #T_4ac1f_row0_col7, #T_4ac1f_row10_col12 {
#   background-color: #0dc2e8;
#   color: #000000;
# }
# ...

# %%
df.isnull()
# Out:
#        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     False  False     False      False        False     False   False
# 1     False  False     False      False        False     False   False
# 2     False  False     False      False        False     False   False
# 3     False  False     False      False        False     False   False
# 4     False  False     False      False        False     False   False
# ...     ...    ...       ...        ...          ...       ...     ...
# 4595  False  False     False      False        False     False   False
# 4596  False  False     False      False        False     False   False
# 4597  False  False     False      False        False     False   False
# 4598  False  False     False      False        False     False   False
# 4599  False  False     False      False        False     False   False
#
#       waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.notnull()
# Out:
#       date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     True   True      True       True         True      True    True
# 1     True   True      True       True         True      True    True
# 2     True   True      True       True         True      True    True
# 3     True   True      True       True         True      True    True
# 4     True   True      True       True         True      True    True
# ...    ...    ...       ...        ...          ...       ...     ...
# 4595  True   True      True       True         True      True    True
# 4596  True   True      True       True         True      True    True
# 4597  True   True      True       True         True      True    True
# 4598  True   True      True       True         True      True    True
# 4599  True   True      True       True         True      True    True
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.notnull().sum()
# Out:
# date             4600
# price            4600
# bedrooms         4600
# bathrooms        4600
# sqft_living      4600
# sqft_lot         4600
# floors           4600
# waterfront       4600
# view             4600
# condition        4600
# sqft_above       4600
# sqft_basement    4600
# yr_built         4600
# yr_renovated     4600
# street           4600
# city             4600
# statezip         4600
# country          4600
# dtype: int64

# %%
Y=df['price']
X=df.drop(['price','date','country','statezip','street','city'],axis=1)
Y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
print(X)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0          3.0       1.50         1340      7912     1.5           0     0
# 1          5.0       2.50         3650      9050     2.0           0     4
# 2          3.0       2.00         1930     11947     1.0           0     0
# 3          3.0       2.25         2000      8030     1.0           0     0
# 4          4.0       2.50         1940     10500     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4595       3.0       1.75         1510      6360     1.0           0     0
# 4596       3.0       2.50         1460      7573     2.0           0     0
# 4597       3.0       2.50         3010      7014     2.0           0     0
# 4598       4.0       2.00         2090      6630     1.0           0     0
# 4599       3.0       2.50         1490      8102     2.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
print(x_train)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 321        4.0       2.50         2550      4630     2.0           0     0
# 118        5.0       2.75         3190     16920     1.0           0     3
# 261        4.0       2.00         2510     13695     1.0           0     0
# 598        3.0       2.75         1250       892     2.0           0     0
# 1770       3.0       2.50         1350      3068     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 1033       3.0       1.50         1270      1443     3.0           0     0
# 3264       2.0       1.00          970      5500     1.0           0     0
# 1653       5.0       2.75         2080     13189     2.0           0     0
# 2607       4.0       2.50         3070     34412     1.0           0     3
# 2732       3.0       1.75         1700      8432     1.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
print(x_train.shape)
# Out:
# (3450, 12)

# %%
print(y_train)
# Out:
# 321      537500.0
# 118     1030000.0
# 261      581000.0
# 598      450000.0
# 1770     613000.0
#           ...
# 1033     440000.0
# 3264     210000.0
# 1653     538888.0
# 2607    1920000.0
# 2732     475000.0
# Name: price, Length: 3450, dtype: float64

# %%
print(y_train.shape)
# Out:
# (3450,)

# %%
print(x_test)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 991        3.0        2.5         2090      4700     2.0           0     0
# 2824       4.0        2.5         2640      8625     2.0           0     0
# 1906       1.0        1.0          650     15364     1.0           0     0
# 1471       4.0        2.0         2510     38141     1.0           0     0
# 1813       4.0        3.5         2790     10125     1.5           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 196        4.0        2.5         2000      5684     2.0           0     0
# 4315       4.0        2.0         1470      8395     1.0           0     0
# 4550       3.0        1.5         1090      8160     1.0           0     0
# 2941       5.0        2.5         2200      4080     1.5           0     0
# 3987       6.0        3.5         3000      8401     1.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
print(x_test.shape)
# Out:
# (1150, 12)

# %%
print(y_test)
# Out:
# 991      289000.0
# 2824     429900.0
# 1906     129000.0
# 1471     600000.0
# 1813    1298000.0
#           ...
# 196      513000.0
# 4315     445000.0
# 4550     214750.0
# 2941     547000.0
# 3987     527000.0
# Name: price, Length: 1150, dtype: float64

# %%
print(y_test.shape)
# Out:
# (1150,)

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Prediction of tht test set Results
y_pred=mlr.predict(x_test)
x_pred=mlr.predict(x_train)

# %%
y_pred
# Out:
# array([507973.63290107, 632523.99900628, 247668.78989767, ...,
#        256897.99250444, 655660.37104162, 629521.41942832])

# %%
df=pd.DataFrame({'Actual':y_test,'predicted':y_pred})
df
# Out:
#          Actual      predicted
# 991    289000.0  507973.632901
# 2824   429900.0  632523.999006
# 1906   129000.0  247668.789898
# 1471   600000.0  577857.167443
# 1813  1298000.0  776909.578640
# ...         ...            ...
# 196    513000.0  439943.318947
# 4315   445000.0  348600.921853
# 4550   214750.0  256897.992504
# 2941   547000.0  655660.371042
# 3987   527000.0  629521.419428
#
# [1150 rows x 2 columns]

# %%
accuracy=mlr.score(x_test,y_test)
accuracy
# Out:
# 0.5553575270099039

# %%
plt.scatter(x_train['bedrooms'],y_train,color="green")
plt.scatter(x_train['bathrooms'],x_pred,color="red")
plt.title("Graph")
plt.xlabel("independent")
plt.ylabel("dependent")
plt.show()
